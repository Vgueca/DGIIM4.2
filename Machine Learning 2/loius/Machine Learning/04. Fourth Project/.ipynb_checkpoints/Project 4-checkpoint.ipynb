# %%
from tensorflow import keras
from keras.utils.layer_utils import count_params
from tensorflow import keras
import tensorflow as tf
import numpy as np

# %%
((x_train, y_train), (x_valid, y_valid)) = keras.datasets.cifar10.load_data()
y_train = keras.utils.to_categorical(y_train)
y_valid = keras.utils.to_categorical(y_valid)

# %% [markdown]
# # Part 1

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
  tf.keras.layers.Dense(10, activation='softmax', kernel_initializer="RandomNormal", bias_initializer="RandomNormal")
])
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=1e-5), metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=100, batch_size=128)
model.save('Model_4_2',save_format='h5')
# Out:
# Epoch 1/100
# 391/391 [==============================] - 2s 3ms/step - loss: 194.3020 - accuracy: 0.1132
# Epoch 2/100
# 391/391 [==============================] - 1s 3ms/step - loss: 148.0009 - accuracy: 0.1457
# Epoch 3/100
# 391/391 [==============================] - 1s 3ms/step - loss: 130.7829 - accuracy: 0.1656
# Epoch 4/100
# 391/391 [==============================] - 1s 3ms/step - loss: 119.9603 - accuracy: 0.1790
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 111.9981 - accuracy: 0.1883
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 105.9246 - accuracy: 0.1965
# Epoch 7/100
# 391/391 [==============================] - 1s 3ms/step - loss: 101.0109 - accuracy: 0.2026
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 96.9778 - accuracy: 0.2066
# Epoch 9/100
# 391/391 [==============================] - 1s 3ms/step - loss: 93.5252 - accuracy: 0.2112
# Epoch 10/100
# ...

# %%
trainable_count = count_params(model.trainable_weights)
non_trainable_count = count_params(model.non_trainable_weights)

print('Total params: {:,}'.format(trainable_count + non_trainable_count))
print('Trainable params: {:,}'.format(trainable_count))
print('Non-trainable params: {:,}'.format(non_trainable_count))
# Out:
# Total params: 30,730
# Trainable params: 30,730
# Non-trainable params: 0

# %%
train_score, train_acc = model.evaluate(x_train, y_train)
test_score, test_acc = model.evaluate(x_valid, y_valid)
print('Test acc : ', test_acc)
print('Train acc: ', train_acc)
# Out:
# ...
# 313/313 [==============================] - 0s 1ms/step - loss: 37.6210 - accuracy: 0.2706
# Test acc :  0.27059999108314514
# Train acc:  0.2800000011920929

# %% [markdown]
# # Part 2

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
  tf.keras.layers.Dense(100, activation='tanh', kernel_initializer="RandomNormal", bias_initializer="RandomNormal"),
  tf.keras.layers.Dense(10, activation='softmax', kernel_initializer="RandomNormal", bias_initializer="RandomNormal")
])
model.compile(loss='categorical_crossentropy', optimizer=keras.optimizers.Adam(learning_rate=1e-5), metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=100, batch_size=128)
model.save('Model_4_2_1',save_format='h5')
# Out:
# Epoch 1/100
# 391/391 [==============================] - 3s 6ms/step - loss: 2.3172 - accuracy: 0.1271
# Epoch 2/100
# 391/391 [==============================] - 3s 7ms/step - loss: 2.2603 - accuracy: 0.1643
# Epoch 3/100
# 391/391 [==============================] - 2s 5ms/step - loss: 2.2365 - accuracy: 0.1809
# Epoch 4/100
# 391/391 [==============================] - 2s 5ms/step - loss: 2.2089 - accuracy: 0.2035
# Epoch 5/100
# 391/391 [==============================] - 2s 5ms/step - loss: 2.1891 - accuracy: 0.2146
# Epoch 6/100
# 391/391 [==============================] - 2s 5ms/step - loss: 2.1706 - accuracy: 0.2245
# Epoch 7/100
# 391/391 [==============================] - 2s 5ms/step - loss: 2.1512 - accuracy: 0.2359
# Epoch 8/100
# 391/391 [==============================] - 2s 5ms/step - loss: 2.1343 - accuracy: 0.2415
# Epoch 9/100
# 391/391 [==============================] - 2s 5ms/step - loss: 2.1188 - accuracy: 0.2444
# Epoch 10/100
# ...

# %%
trainable_count = count_params(model.trainable_weights)
non_trainable_count = count_params(model.non_trainable_weights)

print('Total params: {:,}'.format(trainable_count + non_trainable_count))
print('Trainable params: {:,}'.format(trainable_count))
print('Non-trainable params: {:,}'.format(non_trainable_count))
# Out:
# Total params: 308,310
# Trainable params: 308,310
# Non-trainable params: 0

# %%
train_score, train_acc = model.evaluate(x_train, y_train)
test_score, test_acc = model.evaluate(x_valid, y_valid)
print('Test acc : ', test_acc)
print('Train acc: ', train_acc)
# Out:
# ...
# 313/313 [==============================] - 0s 2ms/step - loss: 1.7976 - accuracy: 0.3600
# Test acc :  0.36000001430511475
# Train acc:  0.3649199903011322

# %% [markdown]
# # Part 3 - Tahn

# %%
trainings_acc = []
tests_acc = []
for i in range(0, 10):
    # MODEL DEFINITION
    model = tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
      tf.keras.layers.Dense(100, activation='tanh', kernel_initializer="RandomNormal", bias_initializer="RandomNormal"),
      tf.keras.layers.Dense(10, activation='softmax', kernel_initializer="RandomNormal", bias_initializer="RandomNormal")
    ])
    opt = keras.optimizers.Adam(learning_rate=1e-5)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    # MODEL FIT
    model.fit(x_train, y_train, epochs=100, batch_size=32)
    # MODEL ACCURACY
    train_score, train_acc = model.evaluate(x_train, y_train)
    test_score, test_acc = model.evaluate(x_valid, y_valid)
    # APPEND TO THE LISTS
    trainings_acc.append(train_acc)
    tests_acc.append(test_acc)
    print(f"ITERATION {i} DONE")
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.2622 - accuracy: 0.1487
# Epoch 2/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.1900 - accuracy: 0.1927
# Epoch 3/100
# 1563/1563 [==============================] - 6s 4ms/step - loss: 2.1472 - accuracy: 0.2165
# Epoch 4/100
# 1563/1563 [==============================] - 7s 5ms/step - loss: 2.1160 - accuracy: 0.2276:  - ETA: 0s - loss: 2.1174 - accura - ETA: 0s - loss: 2.1168
# Epoch 5/100
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.0896 - accuracy: 0.2384
# Epoch 6/100
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.0650 - accuracy: 0.2488
# Epoch 7/100
# 1563/1563 [==============================] - 4s 3ms/step - loss: 2.0401 - accuracy: 0.2633
# Epoch 8/100
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.0276 - accuracy: 0.2693
# Epoch 9/100
# ...

# %%
training_array = np.asarray(trainings_acc)
test_array = np.asarray(tests_acc)
trainingmean = training_array.mean()
testmean = test_array.mean()
testmean
# Out:
# 0.3714300006628036

# %% [markdown]
# # Part 4

# %%
trainings_acc = []
tests_acc = []
for i in range(0, 10):
    # MODEL DEFINITION
    model = tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
      tf.keras.layers.Dense(10, activation='tanh', kernel_initializer="RandomNormal", bias_initializer="RandomNormal"),
      tf.keras.layers.Dense(10, activation='softmax', kernel_initializer="RandomNormal", bias_initializer="RandomNormal")
    ])
    opt = keras.optimizers.Adam(learning_rate=1e-5)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    # MODEL FIT
    model.fit(x_train, y_train, epochs=100, batch_size=128)
    # MODEL ACCURACY
    train_score, train_acc = model.evaluate(x_train, y_train)
    test_score, test_acc = model.evaluate(x_valid, y_valid)
    # APPEND TO THE LISTS
    trainings_acc.append(train_acc)
    tests_acc.append(test_acc)
    print(f"ITERATION {i} DONE")
# Out:
# Epoch 1/100
# 391/391 [==============================] - 3s 4ms/step - loss: 2.3042 - accuracy: 0.1104
# Epoch 2/100
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2976 - accuracy: 0.1184
# Epoch 3/100
# 391/391 [==============================] - 2s 6ms/step - loss: 2.2932 - accuracy: 0.1226: 0s - loss: 2.2945 - ac - ETA: 0s - loss: 2.2932 - accuracy: 0.12
# Epoch 4/100
# 391/391 [==============================] - 1s 4ms/step - loss: 2.2846 - accuracy: 0.1439
# Epoch 5/100
# 391/391 [==============================] - 1s 3ms/step - loss: 2.2803 - accuracy: 0.1571
# Epoch 6/100
# 391/391 [==============================] - 1s 3ms/step - loss: 2.2771 - accuracy: 0.1587
# Epoch 7/100
# 391/391 [==============================] - 1s 3ms/step - loss: 2.2731 - accuracy: 0.1651
# Epoch 8/100
# 391/391 [==============================] - 1s 3ms/step - loss: 2.2685 - accuracy: 0.1699
# Epoch 9/100
# ...

# %%
training_array = np.asarray(trainings_acc)
test_array = np.asarray(tests_acc)
trainingmean = training_array.mean()
test_acc_10 = test_array.mean()

# %%
test_acc_10
# Out:
# 0.2587099984288216

# %%
trainings_acc = []
tests_acc = []
for i in range(0, 10):
    # MODEL DEFINITION
    model = tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
      tf.keras.layers.Dense(1000, activation='tanh', kernel_initializer="RandomNormal", bias_initializer="RandomNormal"),
      tf.keras.layers.Dense(10, activation='softmax', kernel_initializer="RandomNormal", bias_initializer="RandomNormal")
    ])
    opt = keras.optimizers.Adam(learning_rate=1e-5)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    # MODEL FIT
    model.fit(x_train, y_train, epochs=100, batch_size=128)
    # MODEL ACCURACY
    train_score, train_acc = model.evaluate(x_train, y_train)
    test_score, test_acc = model.evaluate(x_valid, y_valid)
    # APPEND TO THE LISTS
    trainings_acc.append(train_acc)
    tests_acc.append(test_acc)
    print(f"ITERATION {i} DONE")
# Out:
# Epoch 1/100
# 391/391 [==============================] - 13s 30ms/step - loss: 2.5041 - accuracy: 0.15695s - loss: 2.6567 - accura - ETA: 5s - - ETA: 0s - loss: 2.515
# Epoch 2/100
# 391/391 [==============================] - 12s 29ms/step - loss: 2.1897 - accuracy: 0.2301
# Epoch 3/100
# 391/391 [==============================] - 12s 31ms/step - loss: 2.0947 - accuracy: 0.25700s - loss: 2.0961
# Epoch 4/100
# 391/391 [==============================] - 11s 29ms/step - loss: 2.0399 - accuracy: 0.2743
# Epoch 5/100
# 391/391 [==============================] - 11s 29ms/step - loss: 2.0039 - accuracy: 0.2865
# Epoch 6/100
# 391/391 [==============================] - 12s 30ms/step - loss: 1.9744 - accuracy: 0.29770s - loss: 1.9
# Epoch 7/100
# 391/391 [==============================] - 12s 31ms/step - loss: 1.9542 - accuracy: 0.30434s - l - ETA: 4s - ETA: 0s - loss: 1.9551 - accu
# Epoch 8/100
# ...

# %%
training_array = np.asarray(trainings_acc)
test_array = np.asarray(tests_acc)
trainingmean = training_array.mean()
test_acc_1000 = test_array.mean()

# %%
test_acc_1000

# %% [markdown]
# # Best

# %%
trainings_acc = []
tests_acc = []
for i in range(0, 10):
    # MODEL DEFINITION
    model = tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
      
      tf.keras.layers.Dense(10, activation='tanh', kernel_initializer="RandomNormal", bias_initializer="RandomNormal"),
      tf.keras.layers.Dense(10, activation='tanh', kernel_initializer="RandomNormal", bias_initializer="RandomNormal"),

      tf.keras.layers.Dense(10, activation='softmax', kernel_initializer="RandomNormal", bias_initializer="RandomNormal")
    ])
    opt = keras.optimizers.Adam(learning_rate=1e-5)
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
    # MODEL FIT
    model.fit(x_train, y_train, epochs=100, batch_size=128)
    # MODEL ACCURACY
    train_score, train_acc = model.evaluate(x_train, y_train)
    test_score, test_acc = model.evaluate(x_valid, y_valid)
    # APPEND TO THE LISTS
    trainings_acc.append(train_acc)
    tests_acc.append(test_acc)
    print(f"ITERATION {i} DONE")
# Out:
# Epoch 1/100
# 391/391 [==============================] - 3s 4ms/step - loss: 2.3027 - accuracy: 0.1000
# Epoch 2/100
# 391/391 [==============================] - 1s 4ms/step - loss: 2.3014 - accuracy: 0.1098
# Epoch 3/100
# 391/391 [==============================] - 2s 4ms/step - loss: 2.3004 - accuracy: 0.1154
# Epoch 4/100
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2993 - accuracy: 0.1143
# Epoch 5/100
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2978 - accuracy: 0.1204
# Epoch 6/100
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2965 - accuracy: 0.1252
# Epoch 7/100
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2946 - accuracy: 0.1357
# Epoch 8/100
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2926 - accuracy: 0.1414
# Epoch 9/100
# 391/391 [==============================] - 2s 4ms/step - loss: 2.2903 - accuracy: 0.1513
# Epoch 10/100
# ...

# %%
training_array = np.asarray(trainings_acc)
test_array = np.asarray(tests_acc)
trainingmean = training_array.mean()
test_acc_1000 = test_array.mean()

# %%
test_acc_1000
# Out:
# 0.22583999931812287
