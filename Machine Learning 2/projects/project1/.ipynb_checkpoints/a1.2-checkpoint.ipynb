# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import time
import sklearn
from sklearn import tree

# %%
import pandas as pd

train_df = pd.read_csv("CalHouseTrain.csv", index_col=0)
test_df = pd.read_csv("CalHouseTest.csv", index_col=0)

# %%
train_df
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0    4.5526      10.0  5.518519   1.005291      1073.0  2.838624     38.67
# 1    5.8541      22.0  6.448105   0.988468      1871.0  3.082372     33.66
# 2    1.9417      32.0  7.647059   2.240642       434.0  2.320856     40.28
# 3    1.5933      37.0  3.998331   1.046745      2489.0  4.155259     32.69
# 4    3.1563      36.0  4.594059   1.075908      1181.0  3.897690     34.21
# ..      ...       ...       ...        ...         ...       ...       ...
# 995  3.7917      16.0  6.155294   0.992941      1090.0  2.564706     39.26
# 996  2.3977      52.0  4.211055   1.221106      1428.0  2.391960     37.77
# 997  2.9760      52.0  4.743590   1.029304       578.0  2.117216     34.10
# 998  5.5750      10.0  6.247573   1.009709      3242.0  3.147573     35.39
# 999  2.4012      18.0  5.234793   1.020681      5303.0  3.225669     37.37
#
#      Longitude    class
# 0      -121.80      low
# 1      -117.97     high
# 2      -124.25      low
# 3      -117.11      low
# 4      -118.37  average
# ..         ...      ...
# 995    -120.99  average
# 996    -122.43     high
# 997    -118.36     high
# 998    -119.08      low
# 999    -120.50      low
#
# [1000 rows x 9 columns]

# %%
test_df
# Out:
#       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1000  2.5000      37.0  3.066519   1.042129      1185.0  2.627494     34.13
# 1001  2.7632      16.0  3.305851   0.970745      1925.0  5.119681     33.74
# 1002  5.9934       2.0  9.896679   1.450185       883.0  3.258303     37.73
# 1003  2.6979      17.0  4.983310   0.973574      1587.0  2.207232     34.00
# 1004  2.3684      35.0  6.196078   1.450980       221.0  2.166667     39.65
# ...      ...       ...       ...        ...         ...       ...       ...
# 1495  6.5847      23.0  8.442748   1.038168      1124.0  2.860051     37.92
# 1496  2.6884      24.0  3.637097   1.045161      3985.0  3.213710     34.08
# 1497  3.1563      42.0  6.187500   1.000000       158.0  4.937500     37.36
# 1498  2.0076      38.0  5.330561   1.135135      1301.0  2.704782     35.64
# 1499  3.8472      35.0  6.296482   1.020101      1316.0  3.306533     37.82
#
#       Longitude    class
# 1000    -118.26  average
# 1001    -117.87  average
# 1002    -121.42  average
# 1003    -117.55      low
# 1004    -121.24      low
# ...         ...      ...
# 1495    -122.03     high
# 1496    -118.10  average
# 1497    -121.92      low
# 1498    -120.69      low
# 1499    -121.17  average
#
# [500 rows x 9 columns]

# %%
x_train = train_df.drop('class', axis=1)
y_test = test_df.drop('class', axis=1)

# %%
from sklearn.tree import DecisionTreeClassifier
# TODO: replace by your own python code
clf = tree.DecisionTreeClassifier(random_state=0)
clf.fit(x_train,train_df['class']) #Class is a categorical feature, should we transform it into numerical?

y_train_pred = []
y_test_pred = []


y_train_pred = clf.predict(x_train)
y_test_pred = clf.predict(y_test)

# %%
y_train_pred
# Out:
# array(['low', 'high', 'low', 'low', 'average', 'high', 'high', 'low',
#        'average', 'high', 'average', 'high', 'average', 'high', 'high',
#        'average', 'average', 'low', 'high', 'high', 'high', 'average',
#        'low', 'low', 'high', 'low', 'low', 'average', 'high', 'high',
#        'high', 'high', 'low', 'average', 'high', 'high', 'low', 'high',
#        'high', 'average', 'low', 'average', 'high', 'high', 'average',
#        'average', 'low', 'low', 'low', 'high', 'high', 'low', 'high',
#        'high', 'high', 'low', 'low', 'low', 'average', 'low', 'low',
#        'average', 'low', 'average', 'average', 'average', 'average',
#        'average', 'low', 'average', 'high', 'high', 'low', 'average',
#        'low', 'average', 'low', 'high', 'high', 'low', 'high', 'low',
#        'low', 'low', 'average', 'low', 'high', 'average', 'average',
#        'low', 'high', 'low', 'low', 'average', 'low', 'average', 'low',
#        'low', 'high', 'average', 'average', 'high', 'low', 'average',
#        'low', 'low', 'average', 'low', 'average', 'average', 'low',
#        'high', 'high', 'low', 'low', 'high', 'high', 'average', 'high',
#        'high', 'average', 'average', 'high', 'high', 'average', 'low',
#        'high', 'high', 'high', 'high', 'low', 'average', 'low', 'average',
#        'low', 'average', 'high', 'average', 'high', 'high', 'average',
#        'low', 'average', 'low', 'average', 'average', 'low', 'low', 'low',
#        'high', 'low', 'average', 'high', 'high', 'average', 'high', 'low',
#        'average', 'average', 'high', 'high', 'average', 'average', 'low',
#        'high', 'average', 'low', 'low', 'low', 'high', 'average',
#        'average', 'low', 'high', 'high', 'low', 'high', 'high', 'low',
#        'high', 'average', 'low', 'average', 'average', 'high', 'high',
#        'high', 'low', 'average', 'high', 'average', 'high', 'average',
#        'low', 'high', 'high', 'low', 'low', 'high', 'high', 'average',
#        'low', 'average', 'high', 'low', 'high', 'low', 'low', 'high',
#        'low', 'low', 'high', 'average', 'high', 'low', 'high', 'average',
#        'low', 'high', 'low', 'average', 'low', 'high', 'low', 'low',
#        'average', 'high', 'average', 'low', 'high', 'high', 'average',
#        'high', 'low', 'high', 'average', 'average', 'low', 'high', 'low',
#        'average', 'low', 'high', 'low', 'high', 'high', 'high', 'average',
#        'average', 'low', 'high', 'high', 'low', 'low', 'low', 'high',
#        'low', 'low', 'average', 'low', 'high', 'low', 'low', 'low', 'low',
#        'high', 'high', 'average', 'high', 'low', 'average', 'high',
#        'high', 'low', 'high', 'low', 'average', 'low', 'low', 'high',
#        'high', 'average', 'high', 'low', 'high', 'average', 'high', 'low',
#        'low', 'low', 'low', 'low', 'high', 'high', 'low', 'low', 'low',
#        'low', 'high', 'average', 'low', 'average', 'average', 'high',
#        'low', 'high', 'low', 'high', 'average', 'low', 'low', 'high',
#        'high', 'average', 'average', 'low', 'high', 'low', 'high',
#        'average', 'low', 'average', 'average', 'high', 'high', 'high',
#        'low', 'average', 'high', 'low', 'low', 'average', 'low',
#        'average', 'low', 'low', 'high', 'low', 'high', 'low', 'low',
#        'high', 'high', 'high', 'high', 'low', 'low', 'high', 'high',
#        'average', 'high', 'average', 'low', 'low', 'average', 'low',
#        'high', 'high', 'low', 'high', 'low', 'high', 'high', 'average',
#        'average', 'average', 'average', 'low', 'average', 'high', 'low',
#        'average', 'high', 'average', 'high', 'high', 'average', 'low',
#        'high', 'low', 'average', 'low', 'high', 'low', 'average', 'high',
#        'average', 'low', 'low', 'low', 'low', 'average', 'average',
#        'high', 'high', 'low', 'low', 'low', 'average', 'high', 'low',
#        'high', 'low', 'high', 'high', 'low', 'low', 'low', 'average',
#        'average', 'low', 'average', 'low', 'average', 'average', 'low',
#        'high', 'low', 'high', 'average', 'low', 'low', 'low', 'average',
#        'average', 'high', 'high', 'low', 'average', 'low', 'low',
#        'average', 'high', 'low', 'average', 'average', 'low', 'low',
#        'average', 'high', 'average', 'low', 'average', 'high', 'high',
#        'low', 'average', 'average', 'high', 'low', 'high', 'average',
#        'high', 'low', 'high', 'high', 'low', 'high', 'average', 'high',
#        'low', 'average', 'low', 'high', 'high', 'high', 'low', 'high',
#        'high', 'average', 'low', 'low', 'low', 'high', 'high', 'low',
#        'high', 'low', 'low', 'low', 'average', 'average', 'low', 'low',
#        'high', 'high', 'high', 'low', 'low', 'low', 'high', 'average',
#        'high', 'low', 'high', 'low', 'low', 'high', 'low', 'low',
#        'average', 'low', 'high', 'low', 'high', 'average', 'high', 'high',
#        'average', 'average', 'low', 'average', 'high', 'average',
#        'average', 'high', 'low', 'average', 'average', 'low', 'low',
#        'average', 'average', 'average', 'low', 'average', 'low',
#        'average', 'low', 'low', 'low', 'high', 'low', 'high', 'low',
#        'low', 'average', 'high', 'high', 'low', 'average', 'average',
#        'high', 'high', 'high', 'high', 'low', 'low', 'high', 'low',
#        'high', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'average',
#        'high', 'low', 'low', 'low', 'low', 'low', 'low', 'average', 'low',
#        'high', 'high', 'low', 'average', 'average', 'high', 'low',
#        'average', 'low', 'low', 'low', 'high', 'high', 'low', 'high',
#        'average', 'low', 'high', 'low', 'low', 'high', 'average', 'low',
#        'average', 'low', 'average', 'average', 'average', 'low',
#        'average', 'low', 'low', 'average', 'high', 'low', 'high', 'high',
#        'low', 'average', 'low', 'high', 'high', 'average', 'high',
#        'average', 'average', 'low', 'average', 'high', 'average', 'low',
#        'average', 'low', 'average', 'low', 'low', 'high', 'low', 'low',
#        'low', 'high', 'high', 'high', 'high', 'average', 'high', 'low',
#        'high', 'average', 'average', 'low', 'low', 'low', 'high', 'low',
#        'low', 'high', 'high', 'low', 'high', 'low', 'low', 'low', 'low',
#        'low', 'high', 'average', 'average', 'low', 'average', 'high',
#        'average', 'average', 'high', 'high', 'average', 'high', 'average',
#        'low', 'low', 'low', 'high', 'high', 'high', 'low', 'low', 'low',
#        'low', 'low', 'high', 'average', 'low', 'low', 'low', 'low', 'low',
#        'average', 'low', 'average', 'low', 'high', 'high', 'low',
#        'average', 'average', 'average', 'average', 'high', 'low',
#        'average', 'low', 'high', 'average', 'average', 'high', 'high',
#        'average', 'low', 'low', 'low', 'average', 'high', 'average',
#        'high', 'average', 'average', 'average', 'average', 'high',
#        'average', 'low', 'low', 'high', 'average', 'high', 'average',
#        'average', 'high', 'average', 'high', 'low', 'high', 'low', 'high',
#        'high', 'average', 'average', 'high', 'low', 'average', 'low',
#        'high', 'average', 'average', 'low', 'low', 'high', 'low',
#        'average', 'high', 'high', 'low', 'high', 'average', 'average',
#        'low', 'average', 'low', 'low', 'high', 'high', 'low', 'average',
#        'low', 'low', 'average', 'high', 'low', 'average', 'average',
#        'average', 'low', 'low', 'average', 'low', 'high', 'low', 'high',
#        'high', 'high', 'low', 'average', 'low', 'high', 'low', 'high',
#        'high', 'low', 'low', 'average', 'low', 'high', 'average', 'high',
#        'low', 'high', 'high', 'low', 'low', 'high', 'high', 'high',
#        'high', 'high', 'average', 'low', 'average', 'low', 'average',
#        'average', 'high', 'low', 'high', 'low', 'low', 'average', 'high',
#        'high', 'low', 'low', 'low', 'average', 'low', 'high', 'high',
#        'average', 'high', 'average', 'high', 'low', 'average', 'average',
#        'average', 'low', 'low', 'high', 'low', 'low', 'average', 'low',
#        'average', 'high', 'low', 'low', 'low', 'average', 'high',
#        'average', 'average', 'high', 'high', 'average', 'low', 'low',
#        'high', 'low', 'average', 'low', 'high', 'high', 'average', 'high',
#        'low', 'average', 'average', 'high', 'low', 'low', 'low', 'low',
#        'low', 'average', 'low', 'low', 'high', 'average', 'low', 'low',
#        'average', 'low', 'high', 'average', 'low', 'average', 'low',
#        'average', 'low', 'average', 'low', 'average', 'average',
#        'average', 'high', 'average', 'average', 'average', 'low', 'low',
#        'low', 'high', 'average', 'average', 'low', 'low', 'average',
#        'low', 'average', 'high', 'average', 'average', 'average', 'low',
#        'low', 'low', 'low', 'average', 'average', 'high', 'high', 'low',
#        'high', 'high', 'average', 'low', 'low', 'average', 'high', 'high',
#        'average', 'high', 'high', 'low', 'high', 'average', 'average',
#        'high', 'average', 'low', 'high', 'high', 'low', 'average',
#        'average', 'low', 'high', 'high', 'low', 'low', 'low', 'high',
#        'high', 'high', 'low', 'low', 'low', 'average', 'low', 'high',
#        'average', 'low', 'low', 'low', 'low', 'low', 'average', 'high',
#        'low', 'low', 'low', 'average', 'average', 'low', 'average',
#        'average', 'average', 'average', 'low', 'high', 'low', 'high',
#        'high', 'average', 'average', 'high', 'high', 'average', 'high',
#        'average', 'high', 'low', 'low', 'average', 'high', 'high', 'low',
#        'low', 'average', 'average', 'high', 'high', 'low', 'low'],
#       dtype=object)

# %%
y_test_pred
# Out:
# array(['high', 'low', 'average', 'average', 'low', 'low', 'low', 'low',
#        'high', 'low', 'low', 'average', 'high', 'average', 'low', 'low',
#        'average', 'average', 'average', 'low', 'low', 'average',
#        'average', 'low', 'average', 'high', 'low', 'low', 'high', 'low',
#        'average', 'average', 'high', 'low', 'low', 'high', 'high', 'high',
#        'average', 'high', 'average', 'low', 'low', 'low', 'high',
#        'average', 'low', 'low', 'high', 'average', 'average', 'average',
#        'low', 'average', 'low', 'average', 'low', 'low', 'low', 'average',
#        'low', 'average', 'low', 'low', 'average', 'low', 'high',
#        'average', 'average', 'low', 'average', 'low', 'high', 'average',
#        'high', 'high', 'high', 'high', 'low', 'high', 'average', 'low',
#        'high', 'high', 'average', 'average', 'low', 'low', 'low', 'high',
#        'high', 'average', 'high', 'low', 'low', 'low', 'low', 'high',
#        'low', 'high', 'low', 'high', 'high', 'high', 'low', 'average',
#        'average', 'low', 'high', 'average', 'average', 'average',
#        'average', 'average', 'low', 'high', 'average', 'high', 'average',
#        'low', 'average', 'low', 'high', 'high', 'average', 'average',
#        'high', 'high', 'low', 'average', 'high', 'low', 'low', 'high',
#        'low', 'high', 'average', 'low', 'average', 'average', 'average',
#        'high', 'high', 'low', 'high', 'low', 'high', 'low', 'average',
#        'low', 'high', 'high', 'low', 'average', 'low', 'high', 'low',
#        'average', 'high', 'low', 'average', 'average', 'low', 'average',
#        'low', 'high', 'low', 'high', 'average', 'high', 'average',
#        'average', 'low', 'average', 'high', 'low', 'average', 'low',
#        'low', 'high', 'low', 'low', 'low', 'low', 'average', 'average',
#        'low', 'average', 'high', 'low', 'low', 'high', 'low', 'high',
#        'low', 'high', 'high', 'average', 'average', 'high', 'high',
#        'high', 'high', 'average', 'low', 'high', 'average', 'high', 'low',
#        'high', 'low', 'low', 'low', 'high', 'average', 'low', 'high',
#        'average', 'high', 'low', 'low', 'low', 'high', 'low', 'low',
#        'average', 'low', 'low', 'average', 'average', 'low', 'low',
#        'high', 'low', 'average', 'average', 'high', 'low', 'low', 'low',
#        'low', 'average', 'average', 'low', 'low', 'high', 'low', 'low',
#        'low', 'high', 'high', 'average', 'high', 'average', 'high',
#        'high', 'low', 'low', 'average', 'average', 'high', 'low', 'high',
#        'average', 'low', 'low', 'low', 'high', 'low', 'high', 'low',
#        'high', 'average', 'high', 'average', 'average', 'low', 'average',
#        'high', 'low', 'high', 'average', 'high', 'low', 'low', 'low',
#        'high', 'high', 'average', 'low', 'average', 'high', 'high', 'low',
#        'average', 'average', 'high', 'low', 'average', 'low', 'average',
#        'high', 'low', 'average', 'high', 'low', 'high', 'average', 'high',
#        'low', 'high', 'low', 'high', 'low', 'high', 'high', 'average',
#        'average', 'high', 'low', 'high', 'average', 'average', 'average',
#        'low', 'average', 'average', 'low', 'low', 'low', 'low', 'low',
#        'high', 'high', 'average', 'low', 'average', 'high', 'high',
#        'average', 'average', 'low', 'low', 'low', 'high', 'low', 'high',
#        'low', 'high', 'low', 'low', 'high', 'low', 'average', 'high',
#        'average', 'average', 'low', 'low', 'low', 'average', 'high',
#        'low', 'low', 'low', 'high', 'high', 'average', 'high', 'high',
#        'average', 'high', 'high', 'high', 'low', 'high', 'low', 'low',
#        'high', 'low', 'low', 'low', 'average', 'average', 'high', 'high',
#        'low', 'low', 'low', 'average', 'high', 'high', 'average', 'low',
#        'high', 'average', 'high', 'average', 'average', 'average', 'high',
#        'low', 'high', 'average', 'low', 'average', 'high', 'low', 'high',
#        'low', 'low', 'low', 'high', 'low', 'average', 'average', 'high',
#        'high', 'low', 'low', 'average', 'low', 'high', 'average', 'low',
#        'high', 'high', 'high', 'average', 'low', 'high', 'low', 'low',
#        'low', 'average', 'average', 'average', 'low', 'low', 'low',
#        'average', 'average', 'average', 'high', 'high', 'high', 'high',
#        'high', 'average', 'low', 'low', 'low', 'high', 'high', 'average',
#        'low', 'low', 'low', 'low', 'low', 'average', 'average', 'average',
#        'low', 'high', 'low', 'low', 'high', 'low', 'high', 'average',
#        'high', 'average', 'high', 'average', 'low', 'high', 'high',
#        'high', 'average', 'average', 'low', 'high', 'low', 'average',
#        'high', 'average', 'low', 'average', 'average', 'average', 'low',
#        'average', 'average', 'high', 'high', 'average', 'average', 'low',
#        'low'], dtype=object)

# %%
clf.tree_.node_count
# Out:
# 431

# %%
a=0
for i in range (len(y_train_pred)):
    if y_train_pred[i] == train_df['class'][i]:
            a=a+1

# %%
from sklearn.metrics import accuracy_score

# %%
training_accuracy = accuracy_score(y_train_pred,train_df['class'])

# %%
training_accuracy
# Out:
# 1.0

# %%
(a/len(y_train_pred))*100
# Out:
# 100.0

# %%
b=0
for i in range (len(y_test_pred)):
    if y_test_pred[i] == test_df['class'][i+1000]:
            b=b+1

# %%
(b/len(y_test_pred))*100
# Out:
# 64.4

# %%
test_accuracy = accuracy_score(y_test_pred,test_df['class'])

# %%
test_accuracy
# Out:
# 0.644

# %%
#Yes if the training data is consistent

# %%
x_train
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0    4.5526      10.0  5.518519   1.005291      1073.0  2.838624     38.67
# 1    5.8541      22.0  6.448105   0.988468      1871.0  3.082372     33.66
# 2    1.9417      32.0  7.647059   2.240642       434.0  2.320856     40.28
# 3    1.5933      37.0  3.998331   1.046745      2489.0  4.155259     32.69
# 4    3.1563      36.0  4.594059   1.075908      1181.0  3.897690     34.21
# ..      ...       ...       ...        ...         ...       ...       ...
# 995  3.7917      16.0  6.155294   0.992941      1090.0  2.564706     39.26
# 996  2.3977      52.0  4.211055   1.221106      1428.0  2.391960     37.77
# 997  2.9760      52.0  4.743590   1.029304       578.0  2.117216     34.10
# 998  5.5750      10.0  6.247573   1.009709      3242.0  3.147573     35.39
# 999  2.4012      18.0  5.234793   1.020681      5303.0  3.225669     37.37
#
#      Longitude
# 0      -121.80
# 1      -117.97
# 2      -124.25
# 3      -117.11
# 4      -118.37
# ..         ...
# 995    -120.99
# 996    -122.43
# 997    -118.36
# 998    -119.08
# 999    -120.50
#
# [1000 rows x 8 columns]

# %%
frame = pd.DataFrame(columns = ["Run", "NodeCount", "TrainAcc", "TestAcc"])

y_train_pred = []
y_test_pred = []
# TODO: replace by your own python code
for i in range(100):
    sampled_df = train_df.sample(n=250,random_state=i) #Sampling training set  
    x_train = sampled_df.drop('class', axis=1) #Dropping class column 
    
    clf = tree.DecisionTreeClassifier(random_state=i) #Building tree
    clf.fit(x_train,sampled_df['class'])  #Fiting classifier with 25% of the training dataset
    
    number_nodes = clf.tree_.node_count 
    y_train_pred = clf.predict(x_train)
    y_test_pred = clf.predict(y_test)
    
    #Computing training accurracy
    sampled_df = sampled_df.reset_index()
    a=0
    for j in range (len(y_train_pred)):
        if y_train_pred[j] == sampled_df['class'][j]:
                a=a+1
    #Computing test accuracy
    b=0
    for z in range (len(y_test_pred)):
        if y_test_pred[z] == test_df['class'][z+1000]:
                b=b+1            
    #Adding results to the dataframe
    frame.loc[i]=[int(i),int(number_nodes),a/250,b/500]
    
mean_nb_nodes = frame['NodeCount'].mean()
mean_train_accur = frame['TrainAcc'].mean()
mean_test_accur = frame['TestAcc'].mean()

# %%
frame
# Out:
#      Run  NodeCount  TrainAcc  TestAcc
# 0    0.0      107.0       1.0    0.604
# 1    1.0      105.0       1.0    0.584
# 2    2.0      107.0       1.0    0.564
# 3    3.0      117.0       1.0    0.594
# 4    4.0      123.0       1.0    0.598
# ..   ...        ...       ...      ...
# 95  95.0       95.0       1.0    0.638
# 96  96.0      121.0       1.0    0.620
# 97  97.0      107.0       1.0    0.624
# 98  98.0      113.0       1.0    0.602
# 99  99.0      129.0       1.0    0.624
#
# [100 rows x 4 columns]

# %%
print(mean_nb_nodes,mean_train_accur,mean_test_accur)
# Out:
# 113.64 1.0 0.6106400000000002

# %%
frame = pd.DataFrame(columns = ["Frac", "Run", "NodeCount", "TrainAcc", "TestAcc"])

y_train_pred = []
y_test_pred = []
fractions= [0.05,0.1,0.2,0.5,0.99]
# TODO: replace by your own python code
for k in range(5):
    for i in range(100):
        sampled_df = train_df.sample(n=int(1000*fractions[k]),random_state=i) #Sampling training set  
        x_train = sampled_df.drop('class', axis=1) #Dropping class column 

        clf = tree.DecisionTreeClassifier(random_state=i) #Building tree
        clf.fit(x_train,sampled_df['class'])  #Fiting classifier with 25% of the training dataset

        number_nodes = clf.tree_.node_count 
        y_train_pred = clf.predict(x_train)
        y_test_pred = clf.predict(y_test)

        #Computing training accurracy
        sampled_df = sampled_df.reset_index()
        a=0
        for j in range (len(y_train_pred)):
            if y_train_pred[j] == sampled_df['class'][j]:
                    a=a+1
        #Computing test accuracy
        b=0
        for z in range (len(y_test_pred)):
            if y_test_pred[z] == test_df['class'][z+1000]:
                    b=b+1            
        #Adding results to the dataframe
        frame.loc[i+100*k]=[fractions[k],i,number_nodes,a/len(y_train_pred),b/len(y_test_pred)]

# %%
frame
# Out:
#      Frac   Run  NodeCount  TrainAcc  TestAcc
# 0    0.05   0.0       27.0       1.0    0.598
# 1    0.05   1.0       25.0       1.0    0.486
# 2    0.05   2.0       29.0       1.0    0.542
# 3    0.05   3.0       29.0       1.0    0.548
# 4    0.05   4.0       25.0       1.0    0.470
# ..    ...   ...        ...       ...      ...
# 495  0.99  95.0      417.0       1.0    0.626
# 496  0.99  96.0      419.0       1.0    0.610
# 497  0.99  97.0      447.0       1.0    0.630
# 498  0.99  98.0      421.0       1.0    0.628
# 499  0.99  99.0      437.0       1.0    0.636
#
# [500 rows x 5 columns]

# %%
frame.boxplot(column= 'NodeCount', by='Frac')
# Out:
# <AxesSubplot:title={'center':'NodeCount'}, xlabel='Frac'>

# %%
frame.boxplot(column= 'TestAcc', by='Frac')
# Out:
# <AxesSubplot:title={'center':'TestAcc'}, xlabel='Frac'>
