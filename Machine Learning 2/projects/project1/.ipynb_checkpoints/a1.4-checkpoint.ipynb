# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import time
import sklearn
from sklearn import tree
from sklearn.metrics import accuracy_score

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
train_df = pd.read_csv("CalHouseTrain.csv", index_col=0)
test_df = pd.read_csv("CalHouseTest.csv", index_col=0)

# %%
x_train = train_df.drop('class', axis=1)
y_test = test_df.drop('class', axis=1)

# %%
y_train_pred = []
y_test_pred = []

# %%
wl = DecisionTreeClassifier(random_state=0, min_impurity_decrease=0.025)
wl.fit(x_train,train_df['class'])
y_train_pred = wl.predict(x_train)
y_test_pred = wl.predict(y_test)

training_accuracy = accuracy_score(y_train_pred,train_df['class'])
test_accuracy = accuracy_score(y_test_pred,test_df['class'])

# %%
test_accuracy
# Out:
# 0.612

# %%
from sklearn.tree import DecisionTreeClassifier

def bagging_fit(train_df, nb_trees, seeds):
    list_trees = []
    for i in range(nb_trees):
        #Sampling with the same size as training dataset, and allowing replacement
        train_sample = train_df.sample(frac=1, replace= True)
        x_train =train_sample.drop('class', axis = 1)
        y_train =train_sample['class']
        
        #Create the Decision Tree with same parameters of the previous question
        clf = DecisionTreeClassifier(random_state=0, min_impurity_decrease=0.025)
        clf.fit(x_train, y_train)
        
        list_trees.append(clf)
    return list_trees  # TODO: replace by your own python code

# %%
def bagging_predict(tree_list, x_test):
    y_predicted = []
    n_observations = x_test.shape[0]
    list_observations = []
    final_prediction = []
    for i in range(n_observations):
        list_observations.append(i)    
    
    frame = pd.DataFrame(columns = list_observations) #We create a empty dataframe with as columns as observations to predict in the test set

    #We add each predicted values from each decision tree to the dataframe, being each prediction a row.
    for i in range(len(tree_list)):
        y_predicted = tree_list[i].predict(x_test)
        frame.loc[i] = y_predicted
    print(frame)
    
    #We compute for each column the value that appeared more often. In case of tie, sorted them alphabetically     
    column_names = frame.columns.tolist()
    for i in range(n_observations):
        count_values = frame[column_names[i]].value_counts()
        print(count_values)
        value = count_values.idxmax()
        
        same_counts = sorted(count_values.index[count_values == count_values[value]])
        most_common_value = same_counts[0]
        final_prediction.append(most_common_value)
        
    return final_prediction  # TODO: replace by your own python code

# %%
tree_list = bagging_fit(train_df,100,[])

# %%
prediction = bagging_predict(tree_list, test_df['class'])
# Out:
# C:\Users\vguec\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12872\3235107559.py in <module>
# ----> 1 prediction = bagging_predict(tree_list, test_df['class'])
#
# ~\AppData\Local\Temp\ipykernel_12872\4027947446.py in bagging_predict(tree_list, x_test)
#      11     #We add each predicted values from each decision tree to the dataframe, being each prediction a row.
#      12     for i in range(len(tree_list)):
# ---> 13         y_predicted = tree_list[i].predict(x_test)
#      14         frame.loc[i] = y_predicted
#      15     print(frame)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     465         """
#     466         check_is_fitted(self)
# --> 467         X = self._validate_X_predict(X, check_input)
#     468         proba = self.tree_.predict(X)
#     469         n_samples = X.shape[0]
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     431         """Validate the training data on predict (probabilities)."""
#     432         if check_input:
# --> 433             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     434             if issparse(X) and (
#     435                 X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     564             raise ValueError("Validation should be done on X, y or both.")
#     565         elif not no_val_X and no_val_y:
# --> 566             X = check_array(X, **check_params)
#     567             out = X
#     568         elif no_val_X and not no_val_y:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744                     array = array.astype(dtype, casting="unsafe", copy=False)
#     745                 else:
# --> 746                     array = np.asarray(array, order=order, dtype=dtype)
#     747             except ComplexWarning as complex_warning:
#     748                 raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     870               dtype='datetime64[ns]')
#     871         """
# --> 872         return np.asarray(self._values, dtype)
#     873
#     874     # ----------------------------------------------------------------------
#
# ValueError: could not convert string to float: 'average'

# %%
prediction
# Out:
# ['low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'average',
#  'average',
#  'average',
#  'low',
#  'average',
#  'average',
#  'average',
#  'average',
#  'average',
#  'low',
#  'low',
#  'average',
#  'low',
#  'average',
#  'average',
#  'average',
#  'low',
#  'high',
#  'low',
#  'low',
#  'average',
#  'high',
#  'low',
#  'low',
#  'average',
#  'average',
#  'low',
#  'average',
#  'high',
#  'low',
#  'low',
#  'high',
#  'average',
#  'high',
#  'average',
#  'high',
#  'low',
#  'high',
#  'average',
#  'average',
#  'average',
#  'low',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'average',
#  'low',
#  'average',
#  'low',
#  'low',
#  'average',
#  'low',
#  'high',
#  'average',
#  'average',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'high',
#  'high',
#  'high',
#  'average',
#  'high',
#  'high',
#  'average',
#  'low',
#  'low',
#  'high',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'low',
#  'high',
#  'low',
#  'high',
#  'average',
#  'high',
#  'low',
#  'average',
#  'low',
#  'low',
#  'high',
#  'average',
#  'low',
#  'average',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'average',
#  'low',
#  'high',
#  'low',
#  'high',
#  'high',
#  'low',
#  'low',
#  'high',
#  'average',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'high',
#  'low',
#  'high',
#  'high',
#  'low',
#  'average',
#  'average',
#  'average',
#  'high',
#  'high',
#  'average',
#  'high',
#  'low',
#  'low',
#  'low',
#  'average',
#  'low',
#  'high',
#  'high',
#  'average',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'average',
#  'low',
#  'low',
#  'high',
#  'average',
#  'average',
#  'low',
#  'high',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'average',
#  'low',
#  'low',
#  'average',
#  'average',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'high',
#  'high',
#  'low',
#  'high',
#  'average',
#  'high',
#  'high',
#  'high',
#  'average',
#  'low',
#  'average',
#  'average',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'average',
#  'average',
#  'high',
#  'low',
#  'high',
#  'high',
#  'average',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'high',
#  'average',
#  'low',
#  'high',
#  'low',
#  'average',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'high',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'high',
#  'high',
#  'low',
#  'high',
#  'low',
#  'high',
#  'average',
#  'low',
#  'low',
#  'high',
#  'average',
#  'high',
#  'low',
#  'high',
#  'high',
#  'low',
#  'average',
#  'low',
#  'average',
#  'low',
#  'average',
#  'low',
#  'high',
#  'average',
#  'high',
#  'high',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'high',
#  'low',
#  'average',
#  'average',
#  'high',
#  'high',
#  'high',
#  'low',
#  'average',
#  'average',
#  'high',
#  'low',
#  'high',
#  'low',
#  'average',
#  'low',
#  'average',
#  'low',
#  'average',
#  'average',
#  'low',
#  'high',
#  'high',
#  'low',
#  'high',
#  'average',
#  'average',
#  'low',
#  'high',
#  'low',
#  'high',
#  'low',
#  'high',
#  'high',
#  'low',
#  'average',
#  'high',
#  'low',
#  'high',
#  'average',
#  'high',
#  'low',
#  'low',
#  'low',
#  'average',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'high',
#  'average',
#  'average',
#  'low',
#  'low',
#  'high',
#  'average',
#  'average',
#  'low',
#  'high',
#  'low',
#  'high',
#  'low',
#  'high',
#  'low',
#  'high',
#  'low',
#  'low',
#  'high',
#  'low',
#  'average',
#  'high',
#  'low',
#  'average',
#  'low',
#  'low',
#  'low',
#  'average',
#  'average',
#  'average',
#  'low',
#  'average',
#  'average',
#  'average',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'average',
#  'average',
#  'low',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'high',
#  'low',
#  'low',
#  'high',
#  'average',
#  'high',
#  'average',
#  'average',
#  'average',
#  'high',
#  'low',
#  'high',
#  'average',
#  'low',
#  'average',
#  'high',
#  'low',
#  'high',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'high',
#  'high',
#  'average',
#  'low',
#  'low',
#  'average',
#  'high',
#  'low',
#  'average',
#  'high',
#  'high',
#  'average',
#  'high',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'high',
#  'average',
#  'average',
#  'average',
#  'low',
#  'low',
#  'average',
#  'low',
#  'low',
#  'high',
#  'high',
#  'high',
#  'high',
#  'low',
#  'average',
#  'high',
#  'low',
#  'low',
#  'average',
#  'low',
#  'average',
#  'high',
#  'low',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'low',
#  'low',
#  'average',
#  'low',
#  'low',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'average',
#  'high',
#  'average',
#  'average',
#  'average',
#  'high',
#  'high',
#  'high',
#  'average',
#  'low',
#  'low',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'average',
#  'average',
#  'average',
#  'average',
#  'low',
#  'low',
#  'high',
#  'low',
#  'low',
#  'low',
#  'average']

# %%
len(prediction)
# Out:
# 500

# %%
accuracy_score(prediction, test_df['class'])
# Out:
# 0.65
